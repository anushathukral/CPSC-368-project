# %%
# !pip install oracledb

# %%
pip install pyopenssl cryptography
# Out:
# ...
#   Using cached cryptography-41.0.7-cp37-abi3-macosx_10_12_universal2.whl (5.3 MB)
# ...
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 42.0.5
#     Uninstalling cryptography-42.0.5:
#       Successfully uninstalled cryptography-42.0.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade cryptography
# Out:
# ...
#   Using cached cryptography-42.0.5-cp39-abi3-macosx_10_12_universal2.whl (5.9 MB)
# ...
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 41.0.7
#     Uninstalling cryptography-41.0.7:
#       Successfully uninstalled cryptography-41.0.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 23.2.0 requires cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0, but you have cryptography 42.0.5 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import oracledb

# %%
dsn = oracledb.makedsn("localhost", 1522, service_name="stu")
connection = oracledb.connect(user="ora_anushat", password="a87607743", dsn=dsn)

# %%
cur = connection.cursor()
data = [r for r in cur.execute('select climate.country, climate.year, population, AverageTemperature, net_forest_conversion, amount from CO2_emissions, Forest_Conversion, Climate, population where Climate.country = Forest_Conversion.country and Forest_Conversion.country = CO2_emissions.country and CO2_emissions.country = Population.country')]
for row in data:
    print(row)
cur.close()

print(data)

#join Forest_Conversion on CO2_Emissions.country = Forest_Conversion.country join Climate on Forest_Conversion.country = Climate.country join Population on Climate.country = Population.country;
# Out:
# ('Algeria', 2000, 30774621, 24, -8800.0, 0.0)
# ('Algeria', 2010, 30774621, 25, -8800.0, 0.0)
# ('Algeria', 2000, 30774621, 24, -8800.0, 0.0)
# ('Algeria', 2010, 30774621, 25, -8800.0, 0.0)
# ('Algeria', 2000, 35856344, 24, -8800.0, 0.0)
# ('Algeria', 2010, 35856344, 25, -8800.0, 0.0)
# ('Algeria', 2000, 35856344, 24, -8800.0, 0.0)
# ('Algeria', 2010, 35856344, 25, -8800.0, 0.0)
# ('Bahrain', 2000, 711442, 27, 10.0, 0.0)
# ('Bahrain', 2010, 711442, 28, 10.0, 0.0)
# ('Bahrain', 2000, 711442, 27, 10.0, 0.0)
# ('Bahrain', 2010, 711442, 28, 10.0, 0.0)
# ('Bahrain', 2000, 1213645, 27, 10.0, 0.0)
# ('Bahrain', 2010, 1213645, 28, 10.0, 0.0)
# ('Bahrain', 2000, 1213645, 27, 10.0, 0.0)
# ('Bahrain', 2010, 1213645, 28, 10.0, 0.0)
# ('Bangladesh', 2000, 129193327, 25, 0.0, 0.0)
# ('Bangladesh', 2010, 129193327, 26, 0.0, 0.0)
# ('Bangladesh', 2000, 129193327, 25, 0.0, 0.0)
# ('Bangladesh', 2010, 129193327, 26, 0.0, 0.0)
# ('Bangladesh', 2000, 129193327, 25, 0.0, 0.0)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)

countries = [entry[0] for entry in data]
years = [entry[1] for entry in data]
population = [entry[2] for entry in data]
average_temp = [entry[3] for entry in data]
net_forest_conversion = [entry[4] for entry in data]
co2_emissions = [entry[5] for entry in data]

plt.scatter(countries, average_temp)
#plt.scatter(countries, population)
plt.scatter(countries, net_forest_conversion)
#plt.scatter(countries, co2_emissions)
plt.xlabel('Country')
plt.ylabel('Trends')
plt.title('Trends in 2000 and 2010')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(countries, population)
