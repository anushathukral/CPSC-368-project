# %%
import pandas as pd

# %%
# Uploaded data files
deforestation_data = pd.read_csv("annual-change-forest-area.csv")
co2_emissions_data = pd.read_csv("CO2_Emissions.csv")
population_data = pd.read_csv("world_population.csv")

# %%
print(co2_emissions_data.columns)
# Out:
# Index(['Country ID', 'Country',
#        'Time Series - CO₂ total emissions  without LULUCF, in 1000 t',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'CO2 emissions, latest year', '% change since 1990',
#        'CO2 emissions \nper capita, \nlatest year'],
#       dtype='object')

# %%
# Selecting only the required columns for country and CO2 emissions in 2000 and 2010
co2_data_subset = co2_emissions_data[['Country', 'Unnamed: 12', 'Unnamed: 22']]

for index, row in co2_data_subset.iterrows():
    country = row['Country']
    co2_2000 = row['Unnamed: 12']
    co2_2010 = row['Unnamed: 22']
    
    co2_insert_statement = f"insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('{country}', 2000, {co2_2000});\n"
    co2_insert_statement += f"insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('{country}', 2010, {co2_2010});\n"
    
    print(co2_insert_statement)
# Out:
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('nan', 2000, 2000);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('nan', 2010, 2010);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Afghanistan', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Afghanistan', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Albania', 2000, 3,507.90);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Albania', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Algeria', 2000, 71,593.26);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Algeria', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Angola', 2000, 16,317.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Angola', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Antigua and Barbuda', 2000, 371.88);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Antigua and Barbuda', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Argentina', 2000, 1,28,323.87);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Argentina', 2010, 1,81,939.49);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Armenia', 2000, 3,199.57);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Armenia', 2010, 4,456.99);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Australia', 2000, 3,50,195.02);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Australia', 2010, 4,05,502.80);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Austria', 2000, 66,162.89);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Austria', 2010, 72,011.84);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Azerbaijan', 2000, 29,010.24);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Azerbaijan', 2010, 26,411.83);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bahamas', 2000, 660.44);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bahamas', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bahrain', 2000, 18,170.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bahrain', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bangladesh', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bangladesh', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Barbados', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Barbados', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belarus', 2000, 54,877.36);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belarus', 2010, 63,156.39);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belgium', 2000, 1,26,735.30);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belgium', 2010, 1,14,561.03);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belize', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Belize', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Benin', 2000, 1,416.38);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Benin', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bhutan', 2000, 498.07);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bhutan', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bolivia (Plurinational State of)', 2000, 7,782.84);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bolivia (Plurinational State of)', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bosnia and Herzegovina', 2000, 11,633.23);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bosnia and Herzegovina', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Botswana', 2000, 3,979.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Botswana', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Brazil', 2000, 3,31,466.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Brazil', 2010, 4,29,844.00);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Brunei Darussalam', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Brunei Darussalam', 2010, 5,882.59);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bulgaria', 2000, 45,305.03);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Bulgaria', 2010, 47,862.93);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Burkina Faso', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Burkina Faso', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Burundi', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Burundi', 2010, 172.97);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cabo Verde', 2000, 284.95);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cabo Verde', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cambodia', 2000, 2,052.58);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cambodia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cameroon', 2000, 2,991.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cameroon', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Canada', 2000, 5,72,162.10);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Canada', 2010, 5,55,549.85);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Central African Republic', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Central African Republic', 2010, 252.59);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Chad', 2000, 304.99);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Chad', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Chile', 2000, 54,750.50);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Chile', 2010, 69,667.00);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('China', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('China', 2010, 87,07,376.00);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Colombia', 2000, 63,813.83);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Colombia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Comoros', 2000, 82.42);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Comoros', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Congo', 2000, 1,292.15);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Congo', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cook Islands', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cook Islands', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Costa Rica', 2000, 5,104.67);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Costa Rica', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Côte d’Ivoire', 2000, 60,372.31);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Côte d’Ivoire', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Croatia', 2000, 19,694.45);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Croatia', 2010, 21,050.86);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cuba', 2000, 26,586.22);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cuba', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cyprus', 2000, 7,145.88);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Cyprus', 2010, 8,089.01);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Czechia', 2000, 1,27,066.45);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Czechia', 2010, 1,17,500.71);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Democratic People's Republic of Korea', 2000, 68,740.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Democratic People's Republic of Korea', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Democratic Republic of the Congo', 2000, 2,644.20);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Democratic Republic of the Congo', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Denmark', 2000, 55,609.69);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Denmark', 2010, 50,678.31);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Djibouti', 2000, 342.02);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Djibouti', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Dominica', 2000, 105.80);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Dominica', 2010, 141.55);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Dominican Republic', 2000, 18,416.75);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Dominican Republic', 2010, 12,572.41);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ecuador', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ecuador', 2010, 37,473.91);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Egypt', 2000, 1,28,227.95);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Egypt', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('El Salvador', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('El Salvador', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Eritrea', 2000, 621.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Eritrea', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Estonia', 2000, 15,244.19);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Estonia', 2010, 18,784.96);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Eswatini', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Eswatini', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ethiopia', 2000, 3,437.90);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ethiopia', 2010, 11,134.35);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Fiji', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Fiji', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Finland', 2000, 57,038.25);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Finland', 2010, 64,099.45);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('France', 2000, 4,19,232.28);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('France', 2010, 3,93,717.82);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Gabon', 2000, 5,157.27);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Gabon', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Gambia', 2000, 218.77);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Gambia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Georgia', 2000, 3,705.20);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Georgia', 2010, 6,634.73);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Germany', 2000, 8,99,780.20);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Germany', 2010, 8,32,669.74);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ghana', 2000, 6,297.67);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ghana', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Greece', 2000, 1,02,999.03);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Greece', 2010, 97,361.50);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Grenada', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Grenada', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guatemala', 2000, 10,578.65);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guatemala', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guinea', 2000, 1,960.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guinea', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guinea-Bissau', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guinea-Bissau', 2010, 2,450.67);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guyana', 2000, 1,688.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Guyana', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Haiti', 2000, 1,447.66);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Haiti', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Honduras', 2000, 4,162.45);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Honduras', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Hungary', 2000, 58,608.27);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Hungary', 2010, 52,123.68);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iceland', 2000, 2,946.47);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iceland', 2010, 3,660.12);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('India', 2000, 10,24,772.86);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('India', 2010, 15,74,362.16);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Indonesia', 2000, 2,89,527.15);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Indonesia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iran (Islamic Republic of)', 2000, 3,65,908.35);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iran (Islamic Republic of)', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iraq', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Iraq', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ireland', 2000, 45,249.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ireland', 2010, 41,747.93);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Israel', 2000, 61,067.82);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Israel', 2010, 65,088.77);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Italy', 2000, 4,68,442.09);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Italy', 2010, 4,33,688.02);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Jamaica', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Jamaica', 2010, 7,283.62);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Japan', 2000, 12,64,844.26);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Japan', 2010, 12,14,068.56);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Jordan', 2000, 16,308.31);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Jordan', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kazakhstan', 2000, 1,48,756.16);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kazakhstan', 2010, 2,50,896.96);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kenya', 2000, 7,927.57);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kenya', 2010, 13,888.30);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kiribati', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kiribati', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kuwait', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kuwait', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kyrgyzstan', 2000, 4,957.14);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Kyrgyzstan', 2010, 6,363.38);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lao People's Democratic Republic', 2000, 1,052.19);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lao People's Democratic Republic', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Latvia', 2000, 7,064.72);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Latvia', 2010, 8,548.88);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lebanon', 2000, 15,570.13);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lebanon', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lesotho', 2000, 805.03);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lesotho', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Liberia', 2000, 3,571.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Liberia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Liechtenstein', 2000, 216.85);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Liechtenstein', 2010, 190.81);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lithuania', 2000, 11,873.92);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Lithuania', 2010, 13,926.74);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Luxembourg', 2000, 8,731.57);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Luxembourg', 2010, 11,219.29);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Madagascar', 2000, 1,747.40);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Madagascar', 2010, 2,057.90);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malawi', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malawi', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malaysia', 2000, 1,36,987.07);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malaysia', 2010, 2,17,972.69);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Maldives', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Maldives', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mali', 2000, 1,562.89);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mali', 2010, 2,743.67);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malta', 2000, 2,545.52);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Malta', 2010, 2,581.76);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Marshall Islands', 2000, 80.92);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Marshall Islands', 2010, 124.94);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mauritania', 2000, 1,137.07);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mauritania', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mauritius', 2000, 2,289.81);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mauritius', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mexico', 2000, 4,07,271.27);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mexico', 2010, 4,89,865.36);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Micronesia (Federated States of)', 2000, 151.99);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Micronesia (Federated States of)', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Monaco', 2000, 100.31);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Monaco', 2010, 77.69);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mongolia', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mongolia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Montenegro', 2000, 2,520.74);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Montenegro', 2010, 2,836.85);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Morocco', 2000, 33,550.80);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Morocco', 2010, 55,823.90);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mozambique', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Mozambique', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Myanmar', 2000, 7,907.24);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Myanmar', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Namibia', 2000, 2,018.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Namibia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nauru', 2000, 13.29);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nauru', 2010, 37.58);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nepal', 2000, 2,894.24);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nepal', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Netherlands', 2000, 1,71,887.44);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Netherlands', 2010, 1,82,117.94);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('New Zealand', 2000, 32,281.35);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('New Zealand', 2010, 34,957.78);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nicaragua', 2000, 3,840.19);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nicaragua', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Niger', 2000, 1,905.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Niger', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nigeria', 2000, 1,16,825.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Nigeria', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Niue', 2000, 4.82);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Niue', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('North Macedonia', 2000, 9,571.65);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('North Macedonia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Norway', 2000, 42,518.55);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Norway', 2010, 46,231.65);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Oman', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Oman', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Palau', 2000, 149.99);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Palau', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Panama', 2000, 5,171.99);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Panama', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Papua New Guinea', 2000, 4,400.45);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Papua New Guinea', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Paraguay', 2000, 3,646.85);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Paraguay', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Peru', 2000, 32,065.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Peru', 2010, 44,943.83);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Philippines', 2000, 82,702.84);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Philippines', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Poland', 2000, 3,17,338.03);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Poland', 2010, 3,34,606.78);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Portugal', 2000, 65,526.59);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Portugal', 2010, 52,989.38);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Qatar', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Qatar', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Republic of Korea', 2000, 4,41,633.44);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Republic of Korea', 2010, 5,94,697.22);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Republic of Moldova', 2000, 6,388.39);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Republic of Moldova', 2010, 9,552.30);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Romania', 2000, 95,455.76);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Romania', 2010, 84,289.72);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Russian Federation', 2000, 14,71,052.23);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Russian Federation', 2010, 16,12,884.81);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Rwanda', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Rwanda', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Kitts and Nevis', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Kitts and Nevis', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Lucia', 2000, 340.19);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Lucia', 2010, 489.43);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Vincent and the Grenadines', 2000, 155.15);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saint Vincent and the Grenadines', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Samoa', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Samoa', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('San Marino', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('San Marino', 2010, 262.74);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sao Tome and Principe', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sao Tome and Principe', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saudi Arabia', 2000, 2,56,720.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Saudi Arabia', 2010, 4,71,246.30);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Senegal', 2000, 6,788.93);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Senegal', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Serbia', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Serbia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Seychelles', 2000, 260.61);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Seychelles', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sierra Leone', 2000, 581.63);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sierra Leone', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Singapore', 2000, 37,755.81);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Singapore', 2010, 45,202.88);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Slovakia', 2000, 41,289.13);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Slovakia', 2010, 38,523.22);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Slovenia', 2000, 15,444.90);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Slovenia', 2010, 16,376.44);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Solomon Islands', 2000, 191.24);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Solomon Islands', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('South Africa', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('South Africa', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('South Sudan', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('South Sudan', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Spain', 2000, 3,11,267.05);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Spain', 2010, 2,83,724.99);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sri Lanka', 2000, 10,922.42);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sri Lanka', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('State of Palestine', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('State of Palestine', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sudan', 2000, 6,183.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sudan', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Suriname', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Suriname', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sweden', 2000, 54,684.43);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Sweden', 2010, 53,042.22);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Switzerland', 2000, 43,617.59);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Switzerland', 2010, 45,049.55);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tajikistan', 2000, 2,538.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tajikistan', 2010, 1,908.00);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Thailand', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Thailand', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Timor-Leste', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Timor-Leste', 2010, 260.84);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Togo', 2000, 1,461.90);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Togo', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tonga', 2000, 94.93);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tonga', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Trinidad and Tobago', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Trinidad and Tobago', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tunisia', 2000, 22,665.18);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tunisia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Turkey', 2000, 2,29,790.60);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Turkey', 2010, 3,14,380.03);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Turkmenistan', 2000, 24,683.20);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Turkmenistan', 2010, 37,325.17);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tuvalu', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Tuvalu', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uganda', 2000, 1,371.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uganda', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ukraine', 2000, 2,85,337.20);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Ukraine', 2010, 2,94,078.32);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Arab Emirates', 2000, 1,02,707.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Arab Emirates', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Kingdom of Great Britain and Northern Ireland', 2000, 5,68,220.06);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Kingdom of Great Britain and Northern Ireland', 2010, 5,12,864.79);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Republic of Tanzania', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United Republic of Tanzania', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United States of America', 2000, 59,98,070.43);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('United States of America', 2010, 56,98,055.78);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uruguay', 2000, 5,576.60);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uruguay', 2010, 6,548.90);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uzbekistan', 2000, 1,08,606.83);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Uzbekistan', 2010, 1,01,762.96);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Vanuatu', 2000, 69.59);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Vanuatu', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Venezuela (Bolivarian Republic of)', 2000, ...);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Venezuela (Bolivarian Republic of)', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Viet Nam', 2000, 55,905.72);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Viet Nam', 2010, 1,46,036.77);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Yemen', 2000, 17,548.00);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Yemen', 2010, 22,341.00);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Zambia', 2000, 1,685.89);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Zambia', 2010, ...);
#
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Zimbabwe', 2000, 24,869.08);
# insert into CO2_Emissions (Country, Year, CO2_Emissions) values ('Zimbabwe', 2010, ...);

# %%
# Selecting only the required columns for entity, year, and net forest conversion
forest_data_subset = deforestation_data[['Entity', 'Year', 'Net forest conversion']]

for index, row in forest_data_subset.iterrows():
    entity = row['Entity']
    year = row['Year']
    net_forest = row['Net forest conversion']
    
    forest_insert_statement = f"insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('{entity}', 2000, {net_forest});\n"
    forest_insert_statement += f"insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('{entity}', 2010, {net_forest});\n"

    print(forest_insert_statement)
# Out:
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2000, -8800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2010, -8800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2000, 33900.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2010, 33900.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2000, 7600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2010, 7600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2000, -1400.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Algeria', 2010, -1400.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2000, -182600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2010, -182600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2000, -316400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2010, -316400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2000, -223400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2010, -223400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2000, -104800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Argentina', 2010, -104800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Aruba', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2000, -206810.0000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2010, -206810.0000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2000, -226799.9999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2010, -226799.9999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2000, 709680.0000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Australia', 2010, 709680.0000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2000, 6249.999999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2010, 6249.999999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2000, 2510.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2010, 2510.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2000, 3600.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2010, 3600.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2000, 3590.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Austria', 2010, 3590.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Azerbaijan', 2000, 9079.999999999998);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Azerbaijan', 2010, 9079.999999999998);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Azerbaijan', 2000, 14159.999999999996);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Azerbaijan', 2010, 14159.999999999996);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2000, 10.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2010, 10.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2000, 10.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2010, 10.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2000, 20.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2010, 20.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2000, 20.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bahrain', 2010, 20.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2000, -3200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2010, -3200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2000, -990.000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2010, -990.000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bangladesh', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2000, 26110.000000000007);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2010, 26110.000000000007);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2000, 19900.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2010, 19900.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2000, 26820.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belarus', 2010, 26820.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belgium', 2000, -110.0000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belgium', 2010, -110.0000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belgium', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belgium', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2000, -14070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2010, -14070.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2000, -6790.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2010, -6790.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2000, -11710.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2010, -11710.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2000, -11160.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Belize', 2010, -11160.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2000, 9930.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2010, 9930.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2000, 9930.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2010, 9930.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2000, 1980.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2010, 1980.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2000, 1980.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bhutan', 2010, 1980.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2000, -270330.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2010, -270330.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2000, -201540.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2010, -201540.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2000, -211760.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2010, -211760.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2000, -238690.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bolivia', 2010, -238690.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2000, -3780940.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2010, -3780940.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2000, -3950790.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2010, -3950790.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2000, -1539179.9999999995);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2010, -1539179.9999999995);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2000, -1453040.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Brazil', 2010, -1453040.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2000, 4800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2010, 4800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2000, 36200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2010, 36200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2000, 19200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2010, 19200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2000, 12000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Bulgaria', 2010, 12000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2000, -8250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2010, -8250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2000, 17140.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2010, 17140.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Burundi', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2000, -90250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2010, -90250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2000, -69700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2010, -69700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2000, -56000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2010, -56000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2000, -56000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cameroon', 2010, -56000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2000, -47100.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2010, -47100.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2000, -47980.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2010, -47980.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2000, -41300.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2010, -41300.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2000, -37520.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Canada', 2010, -37520.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2000, 300.00000000000034);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2010, 300.00000000000034);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2000, 300.00000000000034);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2010, 300.00000000000034);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2000, 300.00000000000017);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cape Verde', 2010, 300.00000000000017);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2000, -20.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2010, -20.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2000, -20.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2010, -20.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cayman Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2000, -30000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2010, -30000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2000, -30000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2010, -30000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2000, -30000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2010, -30000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2000, -30000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Central African Republic', 2010, -30000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2000, 57100.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2010, 57100.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2000, 90820.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2010, 90820.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2000, 174160.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2010, 174160.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2000, 122920.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Chile', 2010, 122920.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2000, 1986000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2010, 1986000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2000, 2360980.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2010, 2360980.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2000, 1936770.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2010, 1936770.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2000, 1936790.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('China', 2010, 1936790.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2000, -222260.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2010, -222260.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2000, -192770.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2010, -192770.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2000, -134630.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2010, -134630.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2000, -198550.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Colombia', 2010, -198550.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2000, -12000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2010, -12000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2000, -12000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2010, -12000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2000, -12000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2010, -12000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2000, -13800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Congo', 2010, -13800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2000, -5020.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2010, -5020.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2000, 1400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2010, 1400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2000, 16370.000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2010, 16370.000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2000, 16370.000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Costa Rica', 2010, 16370.000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2000, 3500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2010, 3500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2000, 400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2010, 400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2000, 3420.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Croatia', 2010, 3420.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2000, 37700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2010, 37700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2000, 49700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2010, 49700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2000, 50400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2010, 50400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2000, 11600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Cuba', 2010, 11600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2000, 4019.999999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2010, 4019.999999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2000, 1490.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2010, 1490.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2000, 7640.000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2010, 7640.000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2000, 750.0000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Denmark', 2010, 750.0000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2000, 40.000000000000014);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Djibouti', 2010, 40.000000000000014);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2000, 37760.000000000015);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2010, 37760.000000000015);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2000, 10070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2010, 10070.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2000, 6110.000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Dominican Republic', 2010, 6110.000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2000, -90170.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2010, -90170.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2000, -70229.99999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2010, -70229.99999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2000, -41800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2010, -41800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2000, -64269.99999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ecuador', 2010, -64269.99999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2000, -4500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2010, -4500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2000, -4500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2010, -4500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2000, -4500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2010, -4500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2000, -4500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('El Salvador', 2010, -4500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2000, -8360.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2010, -8360.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2000, -8360.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2010, -8360.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2000, -8360.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Equatorial Guinea', 2010, -8360.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2000, 9710.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2010, 9710.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2000, 17000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2010, 17000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2000, 3480.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Estonia', 2010, 3480.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2000, -73000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2010, -73000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2000, -73000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2010, -73000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2000, -73000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ethiopia', 2010, -73000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Falkland Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Faroe Islands', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2000, 57030.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2010, 57030.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2000, -20360.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2010, -20360.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2000, 33400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Finland', 2010, 33400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2000, -4560.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2010, -4560.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2000, -4290.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2010, -4290.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2000, -3300.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2010, -3300.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2000, -3430.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('French Guyana', 2010, -3430.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2000, -6110.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2010, -6110.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2000, -5060.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2010, -5060.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2000, -11880.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2010, -11880.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2000, -11880.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gabon', 2010, -11880.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2000, 6180.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2010, 6180.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Georgia', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2000, 5400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2010, 5400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2000, 5500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2010, 5500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2000, 2000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2010, 2000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Germany', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Gibraltar', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Greenland', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2000, -90.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2010, -90.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2000, -69.99999999999999);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2010, -69.99999999999999);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2000, 130.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2010, 130.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2000, -60.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guadeloupe', 2010, -60.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2000, -57200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2010, -57200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2000, -48660.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2010, -48660.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2000, -27360.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2010, -27360.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2000, -11600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guatemala', 2010, -11600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guinea', 2000, -34700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guinea', 2010, -34700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2000, -3790.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2010, -3790.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2000, -4440.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2010, -4440.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2000, -11690.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2010, -11690.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2000, -9200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Guyana', 2010, -9200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2000, -20950.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2010, -20950.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2000, -20280.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2010, -20280.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2000, -22330.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2010, -22330.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2000, -20910.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Honduras', 2010, -20910.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2000, 10730.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2010, 10730.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2000, 12520.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2010, 12520.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2000, 2890.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2010, 2890.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2000, -1560.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Hungary', 2010, -1560.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2000, 1280.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2010, 1280.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2000, 1480.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2010, 1480.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2000, 700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2010, 700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2000, 640.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iceland', 2010, 640.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2000, 365300.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2010, 365300.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2000, 190500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2010, 190500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2000, 266400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2010, 266400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2000, 266400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('India', 2010, 266400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2000, -1726500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2010, -1726500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2000, -162080.00000000003);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2010, -162080.00000000003);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2000, -578940.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Indonesia', 2010, -578940.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2000, 1400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2010, 1400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2000, 700.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2010, 700.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Iraq', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2000, 16869.999999999993);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2010, 16869.999999999993);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2000, 9000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2010, 9000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2000, 6860.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2010, 6860.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2000, 5470.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ireland', 2010, 5470.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Isle of Man', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Italy', 2000, 53810.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Italy', 2010, 53810.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2000, -30.00000000000003);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2010, -30.00000000000003);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2000, 3740.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2010, 3740.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2000, 3800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2010, 3800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2000, 3890.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Jamaica', 2010, 3890.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2000, 140.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2010, 140.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2000, 140.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2010, 140.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kuwait', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2000, 4880.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2010, 4880.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2000, 4430.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2010, 4430.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2000, 12710.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Kyrgyzstan', 2010, 12710.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2000, 13110.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2010, 13110.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2000, 3860.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2010, 3860.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2000, 3870.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Latvia', 2010, 3870.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Liberia', 2000, -30260.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Liberia', 2010, -30260.0);
#
# ...
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Suriname', 2010, -11080.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2000, 9999.999999999998);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2010, 9999.999999999998);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2000, -9000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2010, -9000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2000, -18600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2010, -18600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Sweden', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2000, 4270.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2010, 4270.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2000, 3850.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2010, 3850.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2000, 3440.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2010, 3440.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2000, 3440.0000000000005);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Switzerland', 2010, 3440.0000000000005);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2000, 6000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2010, 6000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2000, 4869.999999999997);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2010, 4869.999999999997);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2000, 3550.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Syria', 2010, 3550.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2000, -372000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2010, -372000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2000, -372000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2010, -372000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2000, -372000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2010, -372000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2000, -469000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tanzania', 2010, -469000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2000, -36300.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2010, -36300.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2000, 107500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2010, 107500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2000, -2400.0000000000055);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2010, -2400.0000000000055);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2000, -37600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Thailand', 2010, -37600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2000, -9320.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2010, -9320.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2000, -2960.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2010, -2960.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2000, -2960.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2010, -2960.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2000, -2960.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Togo', 2010, -2960.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tokelau', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2000, 2390.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2010, 2390.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2000, 1960.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2010, 1960.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2000, 1530.0000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2010, 1530.0000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2000, 1530.0000000000002);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Tunisia', 2010, 1530.0000000000002);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2000, 36490.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2010, 36490.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2000, 93470.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2010, 93470.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2000, 109440.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2010, 109440.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2000, 118010.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Turkey', 2010, 118010.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2000, -41250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2010, -41250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2000, -41250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2010, -41250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2000, -41250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2010, -41250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2000, -41250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uganda', 2010, -41250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2000, 3800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2010, 3800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2000, 21800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2010, 21800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2000, 6600.000000000001);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Ukraine', 2010, 6600.000000000001);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United Kingdom', 2000, 10500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United Kingdom', 2010, 10500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United Kingdom', 2000, 19200.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United Kingdom', 2010, 19200.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2000, 108600.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2010, 108600.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2000, 518400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2010, 518400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2000, 275000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('United States', 2010, 275000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uruguay', 2000, 36230.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uruguay', 2010, 36230.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uruguay', 2000, 37740.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uruguay', 2010, 37740.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2000, 38810.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2010, 38810.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2000, 39960.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2010, 39960.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2000, 28050.000000000004);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Uzbekistan', 2010, 28050.000000000004);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2000, 0.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vatican', 2010, 0.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2000, -287500.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2010, -287500.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2000, -164600.00000000006);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2010, -164600.00000000006);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2000, -164400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2010, -164400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2000, -90420.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Venezuela', 2010, -90420.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2000, 240810.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2010, 240810.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2000, 160400.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2010, 160400.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2000, 134760.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2010, 134760.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2000, 116250.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Vietnam', 2010, 116250.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2000, -7818000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2010, -7818000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2000, -5117000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2010, -5117000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2000, -4801000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2010, -4801000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2000, -5150000.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('World', 2010, -5150000.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2000, -35800.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2010, -35800.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2000, -188180.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2010, -188180.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2000, -188210.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zambia', 2010, -188210.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2000, -46070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2010, -46070.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2000, -46070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2010, -46070.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2000, -46070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2010, -46070.0);
#
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2000, -46070.0);
# insert into Forest_Conversion (Entity, Year, Net_Forest_Conversion) values ('Zimbabwe', 2010, -46070.0);

# %%
# Selecting only the required columns for country and population in 2000 and 2010
population_data_subset = population_data[['Country/Territory', '2000 Population', '2010 Population']]

for index, row in population_data_subset.iterrows():
    country = row['Country/Territory']
    population_2000 = row['2000 Population']
    population_2010 = row['2010 Population']
    
    pop_insert_statement = f"insert into Population (Country, Year, Population) values ('{country}', 2000, {population_2000});\n"
    pop_insert_statement += f"insert into Population (Country, Year, Population) values ('{country}', 2010, {population_2010});\n"
    
    print(pop_insert_statement)
# Out:
# insert into Population (Country, Year, Population) values ('Afghanistan', 2000, 19542982);
# insert into Population (Country, Year, Population) values ('Afghanistan', 2010, 28189672);
#
# insert into Population (Country, Year, Population) values ('Albania', 2000, 3182021);
# insert into Population (Country, Year, Population) values ('Albania', 2010, 2913399);
#
# insert into Population (Country, Year, Population) values ('Algeria', 2000, 30774621);
# insert into Population (Country, Year, Population) values ('Algeria', 2010, 35856344);
#
# insert into Population (Country, Year, Population) values ('American Samoa', 2000, 58230);
# insert into Population (Country, Year, Population) values ('American Samoa', 2010, 54849);
#
# insert into Population (Country, Year, Population) values ('Andorra', 2000, 66097);
# insert into Population (Country, Year, Population) values ('Andorra', 2010, 71519);
#
# insert into Population (Country, Year, Population) values ('Angola', 2000, 16394062);
# insert into Population (Country, Year, Population) values ('Angola', 2010, 23364185);
#
# insert into Population (Country, Year, Population) values ('Anguilla', 2000, 11047);
# insert into Population (Country, Year, Population) values ('Anguilla', 2010, 13172);
#
# insert into Population (Country, Year, Population) values ('Antigua and Barbuda', 2000, 75055);
# insert into Population (Country, Year, Population) values ('Antigua and Barbuda', 2010, 85695);
#
# insert into Population (Country, Year, Population) values ('Argentina', 2000, 37070774);
# insert into Population (Country, Year, Population) values ('Argentina', 2010, 41100123);
#
# insert into Population (Country, Year, Population) values ('Armenia', 2000, 3168523);
# insert into Population (Country, Year, Population) values ('Armenia', 2010, 2946293);
#
# insert into Population (Country, Year, Population) values ('Aruba', 2000, 89101);
# insert into Population (Country, Year, Population) values ('Aruba', 2010, 100341);
#
# insert into Population (Country, Year, Population) values ('Australia', 2000, 19017963);
# insert into Population (Country, Year, Population) values ('Australia', 2010, 22019168);
#
# insert into Population (Country, Year, Population) values ('Austria', 2000, 8010428);
# insert into Population (Country, Year, Population) values ('Austria', 2010, 8362829);
#
# insert into Population (Country, Year, Population) values ('Azerbaijan', 2000, 8190337);
# insert into Population (Country, Year, Population) values ('Azerbaijan', 2010, 9237202);
#
# insert into Population (Country, Year, Population) values ('Bahamas', 2000, 325014);
# insert into Population (Country, Year, Population) values ('Bahamas', 2010, 373272);
#
# insert into Population (Country, Year, Population) values ('Bahrain', 2000, 711442);
# insert into Population (Country, Year, Population) values ('Bahrain', 2010, 1213645);
#
# insert into Population (Country, Year, Population) values ('Bangladesh', 2000, 129193327);
# insert into Population (Country, Year, Population) values ('Bangladesh', 2010, 148391139);
#
# insert into Population (Country, Year, Population) values ('Barbados', 2000, 264657);
# insert into Population (Country, Year, Population) values ('Barbados', 2010, 274711);
#
# insert into Population (Country, Year, Population) values ('Belarus', 2000, 10256483);
# insert into Population (Country, Year, Population) values ('Belarus', 2010, 9731427);
#
# insert into Population (Country, Year, Population) values ('Belgium', 2000, 10264343);
# insert into Population (Country, Year, Population) values ('Belgium', 2010, 10877947);
#
# insert into Population (Country, Year, Population) values ('Belize', 2000, 240406);
# insert into Population (Country, Year, Population) values ('Belize', 2010, 322106);
#
# insert into Population (Country, Year, Population) values ('Benin', 2000, 6998023);
# insert into Population (Country, Year, Population) values ('Benin', 2010, 9445710);
#
# insert into Population (Country, Year, Population) values ('Bermuda', 2000, 61371);
# insert into Population (Country, Year, Population) values ('Bermuda', 2010, 63447);
#
# insert into Population (Country, Year, Population) values ('Bhutan', 2000, 587207);
# insert into Population (Country, Year, Population) values ('Bhutan', 2010, 705516);
#
# insert into Population (Country, Year, Population) values ('Bolivia', 2000, 8592656);
# insert into Population (Country, Year, Population) values ('Bolivia', 2010, 10223270);
#
# insert into Population (Country, Year, Population) values ('Bosnia and Herzegovina', 2000, 4179350);
# insert into Population (Country, Year, Population) values ('Bosnia and Herzegovina', 2010, 3811088);
#
# insert into Population (Country, Year, Population) values ('Botswana', 2000, 1726985);
# insert into Population (Country, Year, Population) values ('Botswana', 2010, 2091664);
#
# insert into Population (Country, Year, Population) values ('Brazil', 2000, 175873720);
# insert into Population (Country, Year, Population) values ('Brazil', 2010, 196353492);
#
# insert into Population (Country, Year, Population) values ('British Virgin Islands', 2000, 20104);
# insert into Population (Country, Year, Population) values ('British Virgin Islands', 2010, 27556);
#
# insert into Population (Country, Year, Population) values ('Brunei', 2000, 333926);
# insert into Population (Country, Year, Population) values ('Brunei', 2010, 396053);
#
# insert into Population (Country, Year, Population) values ('Bulgaria', 2000, 8097691);
# insert into Population (Country, Year, Population) values ('Bulgaria', 2010, 7592273);
#
# insert into Population (Country, Year, Population) values ('Burkina Faso', 2000, 11882888);
# insert into Population (Country, Year, Population) values ('Burkina Faso', 2010, 16116845);
#
# insert into Population (Country, Year, Population) values ('Burundi', 2000, 6307659);
# insert into Population (Country, Year, Population) values ('Burundi', 2010, 9126605);
#
# insert into Population (Country, Year, Population) values ('Cambodia', 2000, 12118841);
# insert into Population (Country, Year, Population) values ('Cambodia', 2010, 14363532);
#
# insert into Population (Country, Year, Population) values ('Cameroon', 2000, 15091594);
# insert into Population (Country, Year, Population) values ('Cameroon', 2010, 19878036);
#
# insert into Population (Country, Year, Population) values ('Canada', 2000, 30683313);
# insert into Population (Country, Year, Population) values ('Canada', 2010, 33963412);
#
# insert into Population (Country, Year, Population) values ('Cape Verde', 2000, 458251);
# insert into Population (Country, Year, Population) values ('Cape Verde', 2010, 521212);
#
# insert into Population (Country, Year, Population) values ('Cayman Islands', 2000, 39658);
# insert into Population (Country, Year, Population) values ('Cayman Islands', 2010, 54074);
#
# insert into Population (Country, Year, Population) values ('Central African Republic', 2000, 3759170);
# insert into Population (Country, Year, Population) values ('Central African Republic', 2010, 4660067);
#
# insert into Population (Country, Year, Population) values ('Chad', 2000, 8259137);
# insert into Population (Country, Year, Population) values ('Chad', 2010, 11894727);
#
# insert into Population (Country, Year, Population) values ('Chile', 2000, 15351799);
# insert into Population (Country, Year, Population) values ('Chile', 2010, 17004162);
#
# insert into Population (Country, Year, Population) values ('China', 2000, 1264099069);
# insert into Population (Country, Year, Population) values ('China', 2010, 1348191368);
#
# insert into Population (Country, Year, Population) values ('Colombia', 2000, 39215135);
# insert into Population (Country, Year, Population) values ('Colombia', 2010, 44816108);
#
# insert into Population (Country, Year, Population) values ('Comoros', 2000, 536758);
# insert into Population (Country, Year, Population) values ('Comoros', 2010, 656024);
#
# insert into Population (Country, Year, Population) values ('Cook Islands', 2000, 15897);
# insert into Population (Country, Year, Population) values ('Cook Islands', 2010, 17212);
#
# insert into Population (Country, Year, Population) values ('Costa Rica', 2000, 3979193);
# insert into Population (Country, Year, Population) values ('Costa Rica', 2010, 4622252);
#
# insert into Population (Country, Year, Population) values ('Croatia', 2000, 4548434);
# insert into Population (Country, Year, Population) values ('Croatia', 2010, 4368682);
#
# insert into Population (Country, Year, Population) values ('Cuba', 2000, 11105791);
# insert into Population (Country, Year, Population) values ('Cuba', 2010, 11290417);
#
# insert into Population (Country, Year, Population) values ('Curacao', 2000, 141424);
# insert into Population (Country, Year, Population) values ('Curacao', 2010, 159380);
#
# insert into Population (Country, Year, Population) values ('Cyprus', 2000, 948237);
# insert into Population (Country, Year, Population) values ('Cyprus', 2010, 1129686);
#
# insert into Population (Country, Year, Population) values ('Czech Republic', 2000, 10234710);
# insert into Population (Country, Year, Population) values ('Czech Republic', 2010, 10464749);
#
# insert into Population (Country, Year, Population) values ('Denmark', 2000, 5340655);
# insert into Population (Country, Year, Population) values ('Denmark', 2010, 5550849);
#
# insert into Population (Country, Year, Population) values ('Djibouti', 2000, 742033);
# insert into Population (Country, Year, Population) values ('Djibouti', 2010, 919199);
#
# insert into Population (Country, Year, Population) values ('Dominica', 2000, 68346);
# insert into Population (Country, Year, Population) values ('Dominica', 2010, 68755);
#
# insert into Population (Country, Year, Population) values ('Dominican Republic', 2000, 8540791);
# insert into Population (Country, Year, Population) values ('Dominican Republic', 2010, 9775755);
#
# insert into Population (Country, Year, Population) values ('DR Congo', 2000, 48616317);
# insert into Population (Country, Year, Population) values ('DR Congo', 2010, 66391257);
#
# insert into Population (Country, Year, Population) values ('Ecuador', 2000, 12626507);
# insert into Population (Country, Year, Population) values ('Ecuador', 2010, 14989585);
#
# insert into Population (Country, Year, Population) values ('Egypt', 2000, 71371371);
# insert into Population (Country, Year, Population) values ('Egypt', 2010, 87252413);
#
# insert into Population (Country, Year, Population) values ('El Salvador', 2000, 5958482);
# insert into Population (Country, Year, Population) values ('El Salvador', 2010, 6114034);
#
# insert into Population (Country, Year, Population) values ('Equatorial Guinea', 2000, 684977);
# insert into Population (Country, Year, Population) values ('Equatorial Guinea', 2010, 1094524);
#
# insert into Population (Country, Year, Population) values ('Eritrea', 2000, 2392880);
# insert into Population (Country, Year, Population) values ('Eritrea', 2010, 3147727);
#
# insert into Population (Country, Year, Population) values ('Estonia', 2000, 1396877);
# insert into Population (Country, Year, Population) values ('Estonia', 2010, 1331535);
#
# insert into Population (Country, Year, Population) values ('Eswatini', 2000, 1030496);
# insert into Population (Country, Year, Population) values ('Eswatini', 2010, 1099920);
#
# insert into Population (Country, Year, Population) values ('Ethiopia', 2000, 67031867);
# insert into Population (Country, Year, Population) values ('Ethiopia', 2010, 89237791);
#
# insert into Population (Country, Year, Population) values ('Falkland Islands', 2000, 3080);
# insert into Population (Country, Year, Population) values ('Falkland Islands', 2010, 3187);
#
# insert into Population (Country, Year, Population) values ('Faroe Islands', 2000, 45660);
# insert into Population (Country, Year, Population) values ('Faroe Islands', 2010, 48410);
#
# insert into Population (Country, Year, Population) values ('Fiji', 2000, 832509);
# insert into Population (Country, Year, Population) values ('Fiji', 2010, 905169);
#
# insert into Population (Country, Year, Population) values ('Finland', 2000, 5176209);
# insert into Population (Country, Year, Population) values ('Finland', 2010, 5363271);
#
# insert into Population (Country, Year, Population) values ('France', 2000, 58665453);
# insert into Population (Country, Year, Population) values ('France', 2010, 62444567);
#
# insert into Population (Country, Year, Population) values ('French Guiana', 2000, 164351);
# insert into Population (Country, Year, Population) values ('French Guiana', 2010, 228453);
#
# insert into Population (Country, Year, Population) values ('French Polynesia', 2000, 250927);
# insert into Population (Country, Year, Population) values ('French Polynesia', 2010, 283788);
#
# insert into Population (Country, Year, Population) values ('Gabon', 2000, 1272935);
# insert into Population (Country, Year, Population) values ('Gabon', 2010, 1711105);
#
# insert into Population (Country, Year, Population) values ('Gambia', 2000, 1437539);
# insert into Population (Country, Year, Population) values ('Gambia', 2010, 1937275);
#
# insert into Population (Country, Year, Population) values ('Georgia', 2000, 4265172);
# insert into Population (Country, Year, Population) values ('Georgia', 2010, 3836831);
#
# insert into Population (Country, Year, Population) values ('Germany', 2000, 81551677);
# insert into Population (Country, Year, Population) values ('Germany', 2010, 81325090);
#
# insert into Population (Country, Year, Population) values ('Ghana', 2000, 19665502);
# insert into Population (Country, Year, Population) values ('Ghana', 2010, 25574719);
#
# insert into Population (Country, Year, Population) values ('Gibraltar', 2000, 27741);
# insert into Population (Country, Year, Population) values ('Gibraltar', 2010, 31262);
#
# insert into Population (Country, Year, Population) values ('Greece', 2000, 11038109);
# insert into Population (Country, Year, Population) values ('Greece', 2010, 11033783);
#
# insert into Population (Country, Year, Population) values ('Greenland', 2000, 56184);
# insert into Population (Country, Year, Population) values ('Greenland', 2010, 56351);
#
# insert into Population (Country, Year, Population) values ('Grenada', 2000, 107432);
# insert into Population (Country, Year, Population) values ('Grenada', 2010, 114039);
#
# insert into Population (Country, Year, Population) values ('Guadeloupe', 2000, 424067);
# insert into Population (Country, Year, Population) values ('Guadeloupe', 2010, 403072);
#
# insert into Population (Country, Year, Population) values ('Guam', 2000, 160188);
# insert into Population (Country, Year, Population) values ('Guam', 2010, 164905);
#
# insert into Population (Country, Year, Population) values ('Guatemala', 2000, 11735894);
# insert into Population (Country, Year, Population) values ('Guatemala', 2010, 14543121);
#
# insert into Population (Country, Year, Population) values ('Guernsey', 2000, 59114);
# insert into Population (Country, Year, Population) values ('Guernsey', 2010, 60782);
#
# insert into Population (Country, Year, Population) values ('Guinea', 2000, 8336967);
# insert into Population (Country, Year, Population) values ('Guinea', 2010, 10270728);
#
# insert into Population (Country, Year, Population) values ('Guinea-Bissau', 2000, 1230849);
# insert into Population (Country, Year, Population) values ('Guinea-Bissau', 2010, 1567220);
#
# insert into Population (Country, Year, Population) values ('Guyana', 2000, 759051);
# insert into Population (Country, Year, Population) values ('Guyana', 2010, 747932);
#
# insert into Population (Country, Year, Population) values ('Haiti', 2000, 8360225);
# insert into Population (Country, Year, Population) values ('Haiti', 2010, 9842880);
#
# insert into Population (Country, Year, Population) values ('Honduras', 2000, 6656725);
# insert into Population (Country, Year, Population) values ('Honduras', 2010, 8450933);
#
# insert into Population (Country, Year, Population) values ('Hong Kong', 2000, 6731195);
# insert into Population (Country, Year, Population) values ('Hong Kong', 2010, 7132438);
#
# insert into Population (Country, Year, Population) values ('Hungary', 2000, 10202055);
# insert into Population (Country, Year, Population) values ('Hungary', 2010, 9986825);
#
# insert into Population (Country, Year, Population) values ('Iceland', 2000, 281462);
# insert into Population (Country, Year, Population) values ('Iceland', 2010, 318333);
#
# insert into Population (Country, Year, Population) values ('India', 2000, 1059633675);
# insert into Population (Country, Year, Population) values ('India', 2010, 1240613620);
#
# insert into Population (Country, Year, Population) values ('Indonesia', 2000, 214072421);
# insert into Population (Country, Year, Population) values ('Indonesia', 2010, 244016173);
#
# insert into Population (Country, Year, Population) values ('Iran', 2000, 65544383);
# insert into Population (Country, Year, Population) values ('Iran', 2010, 75373855);
#
# insert into Population (Country, Year, Population) values ('Iraq', 2000, 24628858);
# insert into Population (Country, Year, Population) values ('Iraq', 2010, 31264875);
#
# insert into Population (Country, Year, Population) values ('Ireland', 2000, 3768950);
# insert into Population (Country, Year, Population) values ('Ireland', 2010, 4524585);
#
# insert into Population (Country, Year, Population) values ('Isle of Man', 2000, 75562);
# insert into Population (Country, Year, Population) values ('Isle of Man', 2010, 83828);
#
# insert into Population (Country, Year, Population) values ('Israel', 2000, 6116958);
# insert into Population (Country, Year, Population) values ('Israel', 2010, 7328445);
#
# insert into Population (Country, Year, Population) values ('Italy', 2000, 56966397);
# insert into Population (Country, Year, Population) values ('Italy', 2010, 59822450);
#
# insert into Population (Country, Year, Population) values ('Ivory Coast', 2000, 16799670);
# insert into Population (Country, Year, Population) values ('Ivory Coast', 2010, 21120042);
#
# insert into Population (Country, Year, Population) values ('Jamaica', 2000, 2612205);
# insert into Population (Country, Year, Population) values ('Jamaica', 2010, 2733896);
#
# insert into Population (Country, Year, Population) values ('Japan', 2000, 126803861);
# insert into Population (Country, Year, Population) values ('Japan', 2010, 128105431);
#
# insert into Population (Country, Year, Population) values ('Jersey', 2000, 86192);
# insert into Population (Country, Year, Population) values ('Jersey', 2010, 96151);
#
# insert into Population (Country, Year, Population) values ('Jordan', 2000, 5056174);
# insert into Population (Country, Year, Population) values ('Jordan', 2010, 6931258);
#
# insert into Population (Country, Year, Population) values ('Kazakhstan', 2000, 15236253);
# insert into Population (Country, Year, Population) values ('Kazakhstan', 2010, 16627837);
#
# insert into Population (Country, Year, Population) values ('Kenya', 2000, 30851606);
# insert into Population (Country, Year, Population) values ('Kenya', 2010, 41517895);
#
# insert into Population (Country, Year, Population) values ('Kiribati', 2000, 88826);
# insert into Population (Country, Year, Population) values ('Kiribati', 2010, 107995);
#
# insert into Population (Country, Year, Population) values ('Kuwait', 2000, 1934901);
# insert into Population (Country, Year, Population) values ('Kuwait', 2010, 2943356);
#
# insert into Population (Country, Year, Population) values ('Kyrgyzstan', 2000, 4935182);
# insert into Population (Country, Year, Population) values ('Kyrgyzstan', 2010, 5483774);
#
# insert into Population (Country, Year, Population) values ('Laos', 2000, 5430853);
# insert into Population (Country, Year, Population) values ('Laos', 2010, 6323418);
#
# insert into Population (Country, Year, Population) values ('Latvia', 2000, 2392530);
# insert into Population (Country, Year, Population) values ('Latvia', 2010, 2101530);
#
# insert into Population (Country, Year, Population) values ('Lebanon', 2000, 4320642);
# insert into Population (Country, Year, Population) values ('Lebanon', 2010, 4995800);
#
# insert into Population (Country, Year, Population) values ('Lesotho', 2000, 1998630);
# insert into Population (Country, Year, Population) values ('Lesotho', 2010, 2022747);
#
# insert into Population (Country, Year, Population) values ('Liberia', 2000, 2895224);
# insert into Population (Country, Year, Population) values ('Liberia', 2010, 4019956);
#
# insert into Population (Country, Year, Population) values ('Libya', 2000, 5154790);
# insert into Population (Country, Year, Population) values ('Libya', 2010, 6491988);
#
# insert into Population (Country, Year, Population) values ('Liechtenstein', 2000, 33026);
# insert into Population (Country, Year, Population) values ('Liechtenstein', 2010, 35926);
#
# insert into Population (Country, Year, Population) values ('Lithuania', 2000, 3599637);
# insert into Population (Country, Year, Population) values ('Lithuania', 2010, 3139019);
#
# insert into Population (Country, Year, Population) values ('Luxembourg', 2000, 435628);
# insert into Population (Country, Year, Population) values ('Luxembourg', 2010, 507070);
#
# insert into Population (Country, Year, Population) values ('Macau', 2000, 431896);
# insert into Population (Country, Year, Population) values ('Macau', 2010, 557297);
#
# insert into Population (Country, Year, Population) values ('Madagascar', 2000, 16216431);
# insert into Population (Country, Year, Population) values ('Madagascar', 2010, 21731053);
#
# insert into Population (Country, Year, Population) values ('Malawi', 2000, 11229387);
# insert into Population (Country, Year, Population) values ('Malawi', 2010, 14718422);
#
# insert into Population (Country, Year, Population) values ('Malaysia', 2000, 22945150);
# insert into Population (Country, Year, Population) values ('Malaysia', 2010, 28717731);
#
# insert into Population (Country, Year, Population) values ('Maldives', 2000, 282507);
# insert into Population (Country, Year, Population) values ('Maldives', 2010, 361575);
#
# insert into Population (Country, Year, Population) values ('Mali', 2000, 11239101);
# insert into Population (Country, Year, Population) values ('Mali', 2010, 15529181);
#
# insert into Population (Country, Year, Population) values ('Malta', 2000, 399212);
# insert into Population (Country, Year, Population) values ('Malta', 2010, 418755);
#
# insert into Population (Country, Year, Population) values ('Marshall Islands', 2000, 54224);
# insert into Population (Country, Year, Population) values ('Marshall Islands', 2010, 53416);
#
# insert into Population (Country, Year, Population) values ('Martinique', 2000, 432543);
# insert into Population (Country, Year, Population) values ('Martinique', 2010, 392181);
#
# insert into Population (Country, Year, Population) values ('Mauritania', 2000, 2695003);
# insert into Population (Country, Year, Population) values ('Mauritania', 2010, 3419461);
#
# insert into Population (Country, Year, Population) values ('Mauritius', 2000, 1215930);
# insert into Population (Country, Year, Population) values ('Mauritius', 2010, 1283330);
#
# insert into Population (Country, Year, Population) values ('Mayotte', 2000, 159215);
# insert into Population (Country, Year, Population) values ('Mayotte', 2010, 211786);
#
# insert into Population (Country, Year, Population) values ('Mexico', 2000, 97873442);
# insert into Population (Country, Year, Population) values ('Mexico', 2010, 112532401);
#
# insert into Population (Country, Year, Population) values ('Micronesia', 2000, 111709);
# insert into Population (Country, Year, Population) values ('Micronesia', 2010, 107588);
#
# insert into Population (Country, Year, Population) values ('Moldova', 2000, 4251573);
# insert into Population (Country, Year, Population) values ('Moldova', 2010, 3678186);
#
# insert into Population (Country, Year, Population) values ('Monaco', 2000, 32465);
# insert into Population (Country, Year, Population) values ('Monaco', 2010, 33178);
#
# insert into Population (Country, Year, Population) values ('Mongolia', 2000, 2450979);
# insert into Population (Country, Year, Population) values ('Mongolia', 2010, 2702520);
#
# insert into Population (Country, Year, Population) values ('Montenegro', 2000, 633324);
# insert into Population (Country, Year, Population) values ('Montenegro', 2010, 631044);
#
# insert into Population (Country, Year, Population) values ('Montserrat', 2000, 5138);
# insert into Population (Country, Year, Population) values ('Montserrat', 2010, 4938);
#
# insert into Population (Country, Year, Population) values ('Morocco', 2000, 28554415);
# insert into Population (Country, Year, Population) values ('Morocco', 2010, 32464865);
#
# insert into Population (Country, Year, Population) values ('Mozambique', 2000, 17768505);
# insert into Population (Country, Year, Population) values ('Mozambique', 2010, 23073723);
#
# insert into Population (Country, Year, Population) values ('Myanmar', 2000, 45538332);
# insert into Population (Country, Year, Population) values ('Myanmar', 2010, 49390988);
#
# insert into Population (Country, Year, Population) values ('Namibia', 2000, 1819141);
# insert into Population (Country, Year, Population) values ('Namibia', 2010, 2099271);
#
# insert into Population (Country, Year, Population) values ('Nauru', 2000, 10377);
# insert into Population (Country, Year, Population) values ('Nauru', 2010, 10241);
#
# insert into Population (Country, Year, Population) values ('Nepal', 2000, 24559500);
# insert into Population (Country, Year, Population) values ('Nepal', 2010, 27161567);
#
# insert into Population (Country, Year, Population) values ('Netherlands', 2000, 15899135);
# insert into Population (Country, Year, Population) values ('Netherlands', 2010, 16617116);
#
# insert into Population (Country, Year, Population) values ('New Caledonia', 2000, 221537);
# insert into Population (Country, Year, Population) values ('New Caledonia', 2010, 261426);
#
# insert into Population (Country, Year, Population) values ('New Zealand', 2000, 3855266);
# insert into Population (Country, Year, Population) values ('New Zealand', 2010, 4346338);
#
# insert into Population (Country, Year, Population) values ('Nicaragua', 2000, 5123222);
# insert into Population (Country, Year, Population) values ('Nicaragua', 2010, 5855734);
#
# insert into Population (Country, Year, Population) values ('Niger', 2000, 11622665);
# insert into Population (Country, Year, Population) values ('Niger', 2010, 16647543);
#
# insert into Population (Country, Year, Population) values ('Nigeria', 2000, 122851984);
# insert into Population (Country, Year, Population) values ('Nigeria', 2010, 160952853);
#
# insert into Population (Country, Year, Population) values ('Niue', 2000, 2074);
# insert into Population (Country, Year, Population) values ('Niue', 2010, 1812);
#
# insert into Population (Country, Year, Population) values ('North Korea', 2000, 23367059);
# insert into Population (Country, Year, Population) values ('North Korea', 2010, 24686435);
#
# insert into Population (Country, Year, Population) values ('North Macedonia', 2000, 2037936);
# insert into Population (Country, Year, Population) values ('North Macedonia', 2010, 2093828);
#
# insert into Population (Country, Year, Population) values ('Northern Mariana Islands', 2000, 80338);
# insert into Population (Country, Year, Population) values ('Northern Mariana Islands', 2010, 54087);
#
# insert into Population (Country, Year, Population) values ('Norway', 2000, 4491202);
# insert into Population (Country, Year, Population) values ('Norway', 2010, 4889741);
#
# insert into Population (Country, Year, Population) values ('Oman', 2000, 2344253);
# insert into Population (Country, Year, Population) values ('Oman', 2010, 2881914);
#
# insert into Population (Country, Year, Population) values ('Pakistan', 2000, 154369924);
# insert into Population (Country, Year, Population) values ('Pakistan', 2010, 194454498);
#
# insert into Population (Country, Year, Population) values ('Palau', 2000, 19726);
# insert into Population (Country, Year, Population) values ('Palau', 2010, 18540);
#
# insert into Population (Country, Year, Population) values ('Palestine', 2000, 3139954);
# insert into Population (Country, Year, Population) values ('Palestine', 2010, 3992278);
#
# insert into Population (Country, Year, Population) values ('Panama', 2000, 3001731);
# insert into Population (Country, Year, Population) values ('Panama', 2010, 3623617);
#
# insert into Population (Country, Year, Population) values ('Papua New Guinea', 2000, 5508297);
# insert into Population (Country, Year, Population) values ('Papua New Guinea', 2010, 7583269);
#
# insert into Population (Country, Year, Population) values ('Paraguay', 2000, 5123819);
# insert into Population (Country, Year, Population) values ('Paraguay', 2010, 5768613);
#
# insert into Population (Country, Year, Population) values ('Peru', 2000, 26654439);
# insert into Population (Country, Year, Population) values ('Peru', 2010, 29229572);
#
# insert into Population (Country, Year, Population) values ('Philippines', 2000, 77958223);
# insert into Population (Country, Year, Population) values ('Philippines', 2010, 94636700);
#
# insert into Population (Country, Year, Population) values ('Poland', 2000, 38504431);
# insert into Population (Country, Year, Population) values ('Poland', 2010, 38597353);
#
# insert into Population (Country, Year, Population) values ('Portugal', 2000, 10300626);
# insert into Population (Country, Year, Population) values ('Portugal', 2010, 10588401);
#
# insert into Population (Country, Year, Population) values ('Puerto Rico', 2000, 3827108);
# insert into Population (Country, Year, Population) values ('Puerto Rico', 2010, 3717922);
#
# insert into Population (Country, Year, Population) values ('Qatar', 2000, 645937);
# insert into Population (Country, Year, Population) values ('Qatar', 2010, 1713504);
#
# insert into Population (Country, Year, Population) values ('Republic of the Congo', 2000, 3134030);
# insert into Population (Country, Year, Population) values ('Republic of the Congo', 2010, 4437884);
#
# insert into Population (Country, Year, Population) values ('Reunion', 2000, 785424);
# insert into Population (Country, Year, Population) values ('Reunion', 2010, 890130);
#
# insert into Population (Country, Year, Population) values ('Romania', 2000, 21919876);
# insert into Population (Country, Year, Population) values ('Romania', 2010, 20335211);
#
# insert into Population (Country, Year, Population) values ('Russia', 2000, 146844839);
# insert into Population (Country, Year, Population) values ('Russia', 2010, 143242599);
#
# insert into Population (Country, Year, Population) values ('Rwanda', 2000, 8109989);
# insert into Population (Country, Year, Population) values ('Rwanda', 2010, 10309031);
#
# insert into Population (Country, Year, Population) values ('Saint Barthelemy', 2000, 7082);
# insert into Population (Country, Year, Population) values ('Saint Barthelemy', 2010, 8988);
#
# insert into Population (Country, Year, Population) values ('Saint Kitts and Nevis', 2000, 45461);
# insert into Population (Country, Year, Population) values ('Saint Kitts and Nevis', 2010, 47403);
#
# insert into Population (Country, Year, Population) values ('Saint Lucia', 2000, 159500);
# insert into Population (Country, Year, Population) values ('Saint Lucia', 2010, 170935);
#
# insert into Population (Country, Year, Population) values ('Saint Martin', 2000, 29610);
# insert into Population (Country, Year, Population) values ('Saint Martin', 2010, 36458);
#
# insert into Population (Country, Year, Population) values ('Saint Pierre and Miquelon', 2000, 6274);
# insert into Population (Country, Year, Population) values ('Saint Pierre and Miquelon', 2010, 6052);
#
# insert into Population (Country, Year, Population) values ('Saint Vincent and the Grenadines', 2000, 113813);
# insert into Population (Country, Year, Population) values ('Saint Vincent and the Grenadines', 2010, 109308);
#
# insert into Population (Country, Year, Population) values ('Samoa', 2000, 184008);
# insert into Population (Country, Year, Population) values ('Samoa', 2010, 194672);
#
# insert into Population (Country, Year, Population) values ('San Marino', 2000, 26823);
# insert into Population (Country, Year, Population) values ('San Marino', 2010, 31608);
#
# insert into Population (Country, Year, Population) values ('Sao Tome and Principe', 2000, 143714);
# insert into Population (Country, Year, Population) values ('Sao Tome and Principe', 2010, 182138);
#
# insert into Population (Country, Year, Population) values ('Saudi Arabia', 2000, 21547390);
# insert into Population (Country, Year, Population) values ('Saudi Arabia', 2010, 29411929);
#
# insert into Population (Country, Year, Population) values ('Senegal', 2000, 9704287);
# insert into Population (Country, Year, Population) values ('Senegal', 2010, 12530121);
#
# insert into Population (Country, Year, Population) values ('Serbia', 2000, 7935022);
# insert into Population (Country, Year, Population) values ('Serbia', 2010, 7653748);
#
# insert into Population (Country, Year, Population) values ('Seychelles', 2000, 80060);
# insert into Population (Country, Year, Population) values ('Seychelles', 2010, 92409);
#
# insert into Population (Country, Year, Population) values ('Sierra Leone', 2000, 4584067);
# insert into Population (Country, Year, Population) values ('Sierra Leone', 2010, 6436698);
#
# insert into Population (Country, Year, Population) values ('Singapore', 2000, 4053602);
# insert into Population (Country, Year, Population) values ('Singapore', 2010, 5163590);
#
# insert into Population (Country, Year, Population) values ('Sint Maarten', 2000, 30489);
# insert into Population (Country, Year, Population) values ('Sint Maarten', 2010, 33034);
#
# insert into Population (Country, Year, Population) values ('Slovakia', 2000, 5376690);
# insert into Population (Country, Year, Population) values ('Slovakia', 2010, 5396424);
#
# insert into Population (Country, Year, Population) values ('Slovenia', 2000, 1984339);
# insert into Population (Country, Year, Population) values ('Slovenia', 2010, 2057286);
#
# insert into Population (Country, Year, Population) values ('Solomon Islands', 2000, 429978);
# insert into Population (Country, Year, Population) values ('Solomon Islands', 2010, 540394);
#
# insert into Population (Country, Year, Population) values ('Somalia', 2000, 8721465);
# insert into Population (Country, Year, Population) values ('Somalia', 2010, 12026649);
#
# insert into Population (Country, Year, Population) values ('South Africa', 2000, 46813266);
# insert into Population (Country, Year, Population) values ('South Africa', 2010, 51784921);
#
# insert into Population (Country, Year, Population) values ('South Korea', 2000, 46788591);
# insert into Population (Country, Year, Population) values ('South Korea', 2010, 48813042);
#
# insert into Population (Country, Year, Population) values ('South Sudan', 2000, 6114440);
# insert into Population (Country, Year, Population) values ('South Sudan', 2010, 9714419);
#
# insert into Population (Country, Year, Population) values ('Spain', 2000, 40741651);
# insert into Population (Country, Year, Population) values ('Spain', 2010, 46572772);
#
# insert into Population (Country, Year, Population) values ('Sri Lanka', 2000, 18776371);
# insert into Population (Country, Year, Population) values ('Sri Lanka', 2010, 20668557);
#
# insert into Population (Country, Year, Population) values ('Sudan', 2000, 26298773);
# insert into Population (Country, Year, Population) values ('Sudan', 2010, 33739933);
#
# insert into Population (Country, Year, Population) values ('Suriname', 2000, 478998);
# insert into Population (Country, Year, Population) values ('Suriname', 2010, 546080);
#
# insert into Population (Country, Year, Population) values ('Sweden', 2000, 8871043);
# insert into Population (Country, Year, Population) values ('Sweden', 2010, 9381729);
#
# insert into Population (Country, Year, Population) values ('Switzerland', 2000, 7182059);
# insert into Population (Country, Year, Population) values ('Switzerland', 2010, 7822435);
#
# insert into Population (Country, Year, Population) values ('Syria', 2000, 16307654);
# insert into Population (Country, Year, Population) values ('Syria', 2010, 22337563);
#
# insert into Population (Country, Year, Population) values ('Taiwan', 2000, 22194731);
# insert into Population (Country, Year, Population) values ('Taiwan', 2010, 23083083);
#
# insert into Population (Country, Year, Population) values ('Tajikistan', 2000, 6272998);
# insert into Population (Country, Year, Population) values ('Tajikistan', 2010, 7621779);
#
# insert into Population (Country, Year, Population) values ('Tanzania', 2000, 34463704);
# insert into Population (Country, Year, Population) values ('Tanzania', 2010, 45110527);
#
# insert into Population (Country, Year, Population) values ('Thailand', 2000, 63066603);
# insert into Population (Country, Year, Population) values ('Thailand', 2010, 68270489);
#
# insert into Population (Country, Year, Population) values ('Timor-Leste', 2000, 878360);
# insert into Population (Country, Year, Population) values ('Timor-Leste', 2010, 1088486);
#
# insert into Population (Country, Year, Population) values ('Togo', 2000, 5008035);
# insert into Population (Country, Year, Population) values ('Togo', 2010, 6571855);
#
# insert into Population (Country, Year, Population) values ('Tokelau', 2000, 1666);
# insert into Population (Country, Year, Population) values ('Tokelau', 2010, 1367);
#
# insert into Population (Country, Year, Population) values ('Tonga', 2000, 102603);
# insert into Population (Country, Year, Population) values ('Tonga', 2010, 107383);
#
# insert into Population (Country, Year, Population) values ('Trinidad and Tobago', 2000, 1332203);
# insert into Population (Country, Year, Population) values ('Trinidad and Tobago', 2010, 1410296);
#
# insert into Population (Country, Year, Population) values ('Tunisia', 2000, 9893316);
# insert into Population (Country, Year, Population) values ('Tunisia', 2010, 10895063);
#
# insert into Population (Country, Year, Population) values ('Turkey', 2000, 64113547);
# insert into Population (Country, Year, Population) values ('Turkey', 2010, 73195345);
#
# insert into Population (Country, Year, Population) values ('Turkmenistan', 2000, 4569132);
# insert into Population (Country, Year, Population) values ('Turkmenistan', 2010, 5267970);
#
# insert into Population (Country, Year, Population) values ('Turks and Caicos Islands', 2000, 18744);
# insert into Population (Country, Year, Population) values ('Turks and Caicos Islands', 2010, 29726);
#
# insert into Population (Country, Year, Population) values ('Tuvalu', 2000, 9638);
# insert into Population (Country, Year, Population) values ('Tuvalu', 2010, 10550);
#
# insert into Population (Country, Year, Population) values ('Uganda', 2000, 24020697);
# insert into Population (Country, Year, Population) values ('Uganda', 2010, 32341728);
#
# insert into Population (Country, Year, Population) values ('Ukraine', 2000, 48879755);
# insert into Population (Country, Year, Population) values ('Ukraine', 2010, 45683020);
#
# insert into Population (Country, Year, Population) values ('United Arab Emirates', 2000, 3275333);
# insert into Population (Country, Year, Population) values ('United Arab Emirates', 2010, 8481771);
#
# insert into Population (Country, Year, Population) values ('United Kingdom', 2000, 58850043);
# insert into Population (Country, Year, Population) values ('United Kingdom', 2010, 62760039);
#
# insert into Population (Country, Year, Population) values ('United States', 2000, 282398554);
# insert into Population (Country, Year, Population) values ('United States', 2010, 311182845);
#
# insert into Population (Country, Year, Population) values ('United States Virgin Islands', 2000, 108185);
# insert into Population (Country, Year, Population) values ('United States Virgin Islands', 2010, 106142);
#
# insert into Population (Country, Year, Population) values ('Uruguay', 2000, 3292224);
# insert into Population (Country, Year, Population) values ('Uruguay', 2010, 3352651);
#
# insert into Population (Country, Year, Population) values ('Uzbekistan', 2000, 24925554);
# insert into Population (Country, Year, Population) values ('Uzbekistan', 2010, 28614227);
#
# insert into Population (Country, Year, Population) values ('Vanuatu', 2000, 192074);
# insert into Population (Country, Year, Population) values ('Vanuatu', 2010, 245453);
#
# insert into Population (Country, Year, Population) values ('Vatican City', 2000, 651);
# insert into Population (Country, Year, Population) values ('Vatican City', 2010, 596);
#
# insert into Population (Country, Year, Population) values ('Venezuela', 2000, 24427729);
# insert into Population (Country, Year, Population) values ('Venezuela', 2010, 28715022);
#
# insert into Population (Country, Year, Population) values ('Vietnam', 2000, 79001142);
# insert into Population (Country, Year, Population) values ('Vietnam', 2010, 87411012);
#
# insert into Population (Country, Year, Population) values ('Wallis and Futuna', 2000, 14723);
# insert into Population (Country, Year, Population) values ('Wallis and Futuna', 2010, 13142);
#
# insert into Population (Country, Year, Population) values ('Western Sahara', 2000, 270375);
# insert into Population (Country, Year, Population) values ('Western Sahara', 2010, 413296);
#
# insert into Population (Country, Year, Population) values ('Yemen', 2000, 18628700);
# insert into Population (Country, Year, Population) values ('Yemen', 2010, 24743946);
#
# insert into Population (Country, Year, Population) values ('Zambia', 2000, 9891136);
# insert into Population (Country, Year, Population) values ('Zambia', 2010, 13792086);
#
# insert into Population (Country, Year, Population) values ('Zimbabwe', 2000, 11834676);
# insert into Population (Country, Year, Population) values ('Zimbabwe', 2010, 12839771);
